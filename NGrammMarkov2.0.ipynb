# %%
from model import PostgresStorage

pg = PostgresStorage.connect(host='vnkrtv.ru', user='vnkrtv', password='Hardpass1337', port=15432, dbname='vnkrtv')

# %%
corpus = list(pg.exec_query('SELECT text FROM posts LIMIT 3000', []))

# %%
import sys
# !{sys.executable} -m pip install razdel
# Out:
# Requirement already satisfied: razdel in /home/vnkrtv/anaconda3/lib/python3.7/site-packages (0.5.0)

# %%
from typing import Generator, Iterable
import re

import nltk
import razdel 


class Tokenizer:
    remove_punctuation = re.compile(r'[^а-яА-ЯёЁ ]')

    @classmethod
    def tokenize(cls, text: str) -> Generator:
        return (cls.remove_punctuation.sub('', sentence.text.lower().strip())
                     for sentence in razdel.sentenize(text))


class TextProcessor:
    tokenizer = Tokenizer()

    @classmethod
    def get_sentences_gens(cls, texts: Iterable, remove_punctuation=True, remove_brackets=True) -> Generator:
        for text in texts:
            for sentence in cls.tokenizer.tokenize(text):
                yield sentence

    @classmethod
    def get_text_gen(cls, text_gen: Iterable) -> Generator:
        for sentence in cls.get_sentences_gens(text_gen):
            yield [_.text for _ in razdel.tokenize(sentence)]

    @classmethod
    def get_ngram_gen(cls, text_gen: Iterable, ngram_size: int = 3) -> Generator:
        for sentence in cls.get_sentences_gens(text_gen):
            yield [''.join(item) for item in nltk.ngrams(sentence, ngram_size)]

# %%
text = corpus[0][0]
list(TextProcessor.get_text_gen([text]))[0][:5], list(TextProcessor.get_ngram_gen([text]))[0][:5]
# Out:
# (['разработчики', 'объявили', 'о', 'появившейся', 'возможности'],
#  ['раз', 'азр', 'зра', 'раб', 'або'])

# %%
import json
from typing import Generator, Dict, List

BEGIN = '__BEGIN__'
END = '__END__'
        
class WordsEncoder:
    counter: int
    word2int: Dict[str, int]
    int2word: Dict[int, str]

    def __init__(self, counter=None, word2int=None, int2word=None):
        if counter and word2int and int2word:
            self.counter = counter
            self.word2int = word2int
            self.int2word = int2word
                        
    def fit(self, text_corpus: Iterable):
        self.counter = 0
        self.word2int = {
            BEGIN: 0,
            END: -1
        }
        self.int2word = {
            0: BEGIN,
            -1: END
        }
        is_gen = isinstance(text_corpus, Generator)
        for sentence in text_corpus:
            for word in sentence:
                if word not in self.word2int:
                    self.counter += 1
                    self.word2int[word] = self.counter
                    self.int2word[self.counter] = word
                    
    def fit_encode(self, text_corpus: Iterable) -> List[List[int]]:
        self.fit(text_corpus)
        return self.encode_text_corpus(text_corpus)

    def encode_words_list(self, words_list: list) -> list:
        return [self.word2int[word] for word in words_list]

    def encode_text_corpus(self, text_corpus: list) -> list:
        """List of lists of words"""
        return [self.encode_words_list(words_list) for words_list in text_corpus]

    def encode_text_corpus_gen(self, text_corpus_gen: Generator) -> Generator:
        """List of lists of words"""
        return (self.encode_words_list(sentence.split()) for sentence in text_corpus_gen)

    def decode_codes_list(self, codes_list: list) -> list:
        return [self.int2word[code] for code in codes_list]

    def to_dict(self):
        """
        Returns the underlying data as a Python dict.
        """
        return {
            "counter": self.counter,
            "word2int": self.word2int,
            "int2word": self.int2word
        }

    def to_json(self):
        """
        Returns the underlying data as a JSON string.
        """
        return json.dumps(self.to_dict())

    @classmethod
    def from_dict(cls, obj):
        int2word = obj["int2word"]
        for key in int2word:
            int2word[int(key)] = int2word.pop(key)
        return cls(
            None,
            counter=obj["counter"],
            word2int=obj["word2int"],
            int2word=int2word
        )

    @classmethod
    def from_json(cls, json_str):
        return cls.from_dict(json.loads(json_str))

# %%
from typing import Iterable, Generator, Dict, List, Any
import re
import logging
import operator
import random
import bisect
import json
import copy


def accumulate(iterable: Iterable[Any], func=operator.add) -> Generator:
    it = iter(iterable)
    total = next(it)
    yield total
    for element in it:
        total = func(total, element)
        yield total

def compile_next(next_dict: Dict[tuple, dict]) -> List[list]:
    words = list(next_dict.keys())
    cff = list(accumulate(next_dict.values()))
    return [words, cff]

class EncodedChain:
    
    model: Dict[tuple, list]
    state_size: int

    def __init__(self, corpus: Iterable[list], state_size: int, model=None):
        self.state_size = state_size
        self.model = model or self.build(corpus, self.state_size)
        
    def get_random_init_state() -> tuple:
        return random.choice(list(self.model.keys()))

    def build(self, corpus, state_size) -> Dict[tuple, list]:
        model = {}

        for run in corpus:
            items = run + [ END ]
            for i in range(len(run) + 1 - state_size):
                state = tuple(items[i:i+state_size])
                follow = items[i+state_size]
                if follow != END:
                    follow = follow[-1]
                if state not in model:
                    model[state] = {}

                if follow not in model[state]:
                    model[state][follow] = 0

                model[state][follow] += 1
                
        model = { state: compile_next(next_dict) for (state, next_dict) in model.items() }
        return model

    def move(self, state: tuple) -> list:
        choices, cumdist = self.model.get(state, [None, None])
        if not choices:
            return END
        r = random.random() * cumdist[-1]
        selection = choices[bisect.bisect(cumdist, r)]
        return selection

    def gen(self, init_state: tuple = None) -> Generator:
        state = init_state
        while True:
            next_word = self.move(state)
            if next_word == END: 
                break
            
            yield next_word
            state = state[1:] + (state[-1][1:] + next_word, )

    def walk(self, init_state: tuple = None) -> list:
        return list(self.gen(init_state))

    def to_json(self) -> str:
        return json.dumps(list(self.model.items()))

    @classmethod
    def from_json(cls, json_thing: Any):
        if isinstance(json_thing, str):
            obj = json.loads(json_thing)
        else:
            obj = json_thing

        if isinstance(obj, list):
            rehydrated = dict((tuple(item[0]), item[1]) for item in obj)
        elif isinstance(obj, dict):
            rehydrated = obj
        else:
            raise ValueError("Object should be dict or list")

        state_size = len(list(rehydrated.keys())[0])

        inst = cls(None, state_size, rehydrated)
        return inst

# %%
train_corpus = list(TextProcessor.get_ngram_gen([text], 5))
encoder = WordsEncoder()
encoded_corpus = encoder.fit_encode(train_corpus)

# %%
chain = EncodedChain(train_corpus, state_size=2)

# %%
chain.model
# Out:
# {('разра', 'азраб'): [['о'], [1]],
#  ('азраб', 'зрабо'): [['т'], [1]],
#  ('зрабо', 'работ'): [['ч'], [1]],
#  ('работ', 'аботч'): [['и'], [1]],
#  ('аботч', 'ботчи'): [['к'], [1]],
#  ('ботчи', 'отчик'): [['и'], [1]],
#  ('отчик', 'тчики'): [[' '], [1]],
#  ('тчики', 'чики '): [[' '], [1]],
#  ('чики ', 'ики  '): [['о'], [1]],
#  ('ики  ', 'ки  о'): [['б', ' '], [1, 2]],
#  ('ки  о', 'и  об'): [['ъ'], [1]],
#  ('и  об', '  объ'): [['я'], [1]],
#  ('  объ', ' объя'): [['в'], [1]],
#  (' объя', 'объяв'): [['и'], [1]],
#  ('объяв', 'бъяви'): [['л'], [1]],
#  ('бъяви', 'ъявил'): [['и'], [1]],
#  ('ъявил', 'явили'): [[' '], [1]],
#  ('явили', 'вили '): [['о'], [1]],
#  ('вили ', 'или о'): [[' '], [1]],
#  ('или о', 'ли о '): [['п'], [1]],
#  ('ли о ', 'и о п'): [['о'], [1]],
#  ('и о п', ' о по'): [['я'], [1]],
#  (' о по', 'о поя'): [['в'], [1]],
#  ('о поя', ' появ'): [['и'], [1]],
#  (' появ', 'появи'): [['в'], [1]],
#  ('появи', 'оявив'): [['ш'], [1]],
#  ('оявив', 'явивш'): [['е'], [1]],
#  ('явивш', 'вивше'): [['й'], [1]],
#  ('вивше', 'ившей'): [['с'], [1]],
#  ('ившей', 'вшейс'): [['я'], [1]],
#  ('вшейс', 'шейся'): [[' '], [1]],
#  ('шейся', 'ейся '): [['в'], [1]],
#  ('ейся ', 'йся в'): [['о'], [1]],
#  ('йся в', 'ся во'): [['з'], [1]],
#  ('ся во', 'я воз'): [['м'], [1]],
#  ('я воз', ' возм'): [['о'], [1]],
#  (' возм', 'возмо'): [['ж'], [1]],
#  ('возмо', 'озмож'): [['н'], [1]],
#  ('озмож', 'зможн'): [['о'], [1]],
#  ('зможн', 'можно'): [['с'], [1]],
#  ('можно', 'ожнос'): [['т'], [1]],
#  ('ожнос', 'жност'): [['и'], [1]],
#  ('жност', 'ности'): [[' '], [1]],
#  ('ности', 'ости '): [['д', 'п'], [1, 2]],
#  ('ости ', 'сти д'): [['о'], [1]],
#  ('сти д', 'ти до'): [['б'], [1]],
#  ('ти до', 'и доб'): [['а'], [1]],
#  ('и доб', ' доба'): [['в'], [1]],
#  (' доба', 'добав'): [['л'], [2]],
#  ('добав', 'обавл'): [['я', 'е'], [1, 2]],
#  ('обавл', 'бавля'): [['т'], [1]],
#  ('бавля', 'авлят'): [['ь'], [1]],
#  ('авлят', 'влять'): [[' '], [1]],
#  ('влять', 'лять '): [['в'], [1]],
#  ('лять ', 'ять в'): [[' '], [1]],
#  ('ять в', 'ть в '): [['п'], [1]],
#  ('ть в ', 'ь в п'): [['р'], [1]],
#  ('ь в п', ' в пр'): [['о'], [1]],
#  (' в пр', 'в про'): [['ф'], [2]],
#  ('в про', ' проф'): [['и'], [2]],
#  (' проф', 'профи'): [['л'], [2]],
#  ('профи', 'рофил'): [['ь'], [2]],
#  ('рофил', 'офиль'): [[' '], [2]],
#  ('офиль', 'филь '): [['с', ' '], [1, 2]],
#  ('филь ', 'иль с'): [['е'], [1]],
#  ('иль с', 'ль се'): [['р'], [1]],
#  ('ль се', 'ь сер'): [['т'], [1]],
#  ('ь сер', ' серт'): [['и'], [2]],
#  (' серт', 'серти'): [['ф'], [5]],
#  ('серти', 'ертиф'): [['и'], [5]],
#  ('ертиф', 'ртифи'): [['к'], [5]],
#  ('ртифи', 'тифик'): [['а'], [5]],
#  ('тифик', 'ифика'): [['т'], [5]],
#  ('ифика', 'фикат'): [['ы', 'о'], [4, 5]],
#  ('фикат', 'икаты'): [[' '], [4]],
#  ('икаты', 'каты '): [['и', ' ', 'с', 'п'], [1, 2, 3, 4]],
#  ('каты ', 'аты и'): [[' '], [1]],
#  ('аты и', 'ты и '): [['д'], [1]],
#  ('ты и ', 'ы и д'): [['и'], [1]],
#  ('ы и д', ' и ди'): [['п'], [1]],
#  (' и ди', 'и дип'): [['л'], [1]],
#  ('и дип', ' дипл'): [['о'], [1]],
#  (' дипл', 'дипло'): [['м'], [1]],
#  ('дипло', 'иплом'): [['ы'], [1]],
#  ('иплом', 'пломы'): [[' '], [1]],
#  ('пломы', 'ломы '): [['о'], [1]],
#  ('ломы ', 'омы о'): [['т'], [1]],
#  ('омы о', 'мы от'): [[' '], [1]],
#  ('мы от', 'ы от '): [['о'], [1]],
#  ('ы от ', ' от о'): [['н'], [1]],
#  (' от о', 'от он'): [['л'], [1]],
#  ('от он', 'т онл'): [['а'], [1]],
#  ('т онл', ' онла'): [['й'], [1]],
#  (' онла', 'онлай'): [['н'], [3]],
#  ('онлай', 'нлайн'): [['к', 'в', ' '], [1, 2, 3]],
#  ('нлайн', 'лайнк'): [['у'], [1]],
#  ('лайнк', 'айнку'): [['р'], [1]],
#  ('айнку', 'йнкур'): [['с'], [1]],
#  ('йнкур', 'нкурс'): [['о'], [1]],
#  ('нкурс', 'курсо'): [['в'], [1]],
#  ('курсо', 'урсов'): [[' ', '__END__'], [1, 2]],
#  ('урсов', 'рсов '): [['и'], [1]],
#  ('рсов ', 'сов и'): [[' '], [1]],
#  ('сов и', 'ов и '): [['у'], [1]],
#  ('ов и ', 'в и у'): [['н'], [1]],
#  ('в и у', ' и ун'): [['и'], [1]],
#  (' и ун', 'и уни'): [['в'], [1]],
#  ('и уни', ' унив'): [['е'], [1]],
#  (' унив', 'униве'): [['р'], [6]],
#  ('униве', 'нивер'): [['с'], [6]],
#  ('нивер', 'иверс'): [['и'], [6]],
#  ('иверс', 'верси'): [['т'], [6]],
#  ('верси', 'ерсит'): [['е'], [6]],
#  ('ерсит', 'рсите'): [['т'], [6]],
#  ('рсите', 'ситет'): [['о', ' '], [2, 6]],
#  ('ситет', 'итето'): [['в'], [2]],
#  ('итето', 'тетов'): [[' '], [2]],
#  ('тетов', 'етов '): [['н', 'у'], [1, 2]],
#  ('етов ', 'тов н'): [['а'], [1]],
#  ('тов н', 'ов на'): [['ж'], [1]],
#  ('ов на', 'в наж'): [['а'], [1]],
#  ('в наж', ' нажа'): [['т'], [1]],
#  (' нажа', 'нажат'): [['и'], [1]],
#  ('нажат', 'ажати'): [['е'], [1]],
#  ('ажати', 'жатие'): [['м'], [1]],
#  ('жатие', 'атием'): [[' '], [1]],
#  ('атием', 'тием '): [['о'], [1]],
#  ('тием ', 'ием о'): [['д'], [1]],
#  ('ием о', 'ем од'): [['н'], [1]],
#  ('ем од', 'м одн'): [['о'], [1]],
#  ('м одн', ' одно'): [['й'], [1]],
#  (' одно', 'одной'): [[' '], [1]],
#  ('одной', 'дной '): [['к'], [1]],
#  ('дной ', 'ной к'): [['н'], [1]],
#  ('ной к', 'ой кн'): [['о'], [1]],
#  ('ой кн', 'й кно'): [['п'], [1]],
#  ('й кно', ' кноп'): [['к'], [1]],
#  (' кноп', 'кнопк'): [['и', 'у'], [1, 2]],
#  ('кнопк', 'нопки'): [['__END__'], [1]],
#  ('это р', 'то ра'): [['с'], [1]],
#  ('то ра', 'о рас'): [['ш'], [1]],
#  ('о рас', ' расш'): [['и'], [1]],
#  (' расш', 'расши'): [['р'], [1]],
#  ('расши', 'асшир'): [['е'], [1]],
#  ('асшир', 'сшире'): [['н'], [1]],
#  ('сшире', 'ширен'): [['и'], [1]],
#  ('ширен', 'ирени'): [['е'], [1]],
#  ('ирени', 'рение'): [[' '], [1]],
#  ('рение', 'ение '): [['б'], [1]],
#  ('ение ', 'ние б'): [['ы'], [1]],
#  ('ние б', 'ие бы'): [['л'], [1]],
#  ('ие бы', 'е был'): [['о'], [1]],
#  ('е был', ' было'): [[' '], [1]],
#  (' было', 'было '): [['а'], [1]],
#  ('было ', 'ыло а'): [['н'], [1]],
#  ('ыло а', 'ло ан'): [['о'], [1]],
#  ('ло ан', 'о ано'): [['н'], [1]],
#  ('о ано', ' анон'): [['с'], [1]],
#  (' анон', 'анонс'): [['и'], [1]],
#  ('анонс', 'нонси'): [['р'], [1]],
#  ('нонси', 'онсир'): [['о'], [1]],
#  ('онсир', 'нсиро'): [['в'], [1]],
#  ('нсиро', 'сиров'): [['а'], [1]],
#  ('сиров', 'ирова'): [['н'], [1]],
#  ('ирова', 'рован'): [['о'], [1]],
#  ('рован', 'овано'): [[' '], [1]],
#  ('овано', 'вано '): [['в'], [1]],
#  ('вано ', 'ано в'): [[' '], [1]],
#  ('ано в', 'но в '): [['р'], [1]],
#  ('но в ', 'о в р'): [['а'], [1]],
#  ('о в р', ' в ра'): [['м'], [1]],
#  (' в ра', 'в рам'): [['к'], [1]],
#  ('в рам', ' рамк'): [['а'], [1]],
#  (' рамк', 'рамка'): [['х'], [1]],
#  ('рамка', 'амках'): [[' '], [1]],
#  ('амках', 'мках '): [['п'], [1]],
#  ('мках ', 'ках п'): [['р'], [1]],
#  ('ках п', 'ах пр'): [['о'], [1]],
#  ('ах пр', 'х про'): [['д'], [1]],
#  ('х про', ' прод'): [['о'], [1]],
#  (' прод', 'продо'): [['л'], [1]],
#  ('продо', 'родол'): [['ж'], [1]],
#  ('родол', 'одолж'): [['е'], [1]],
#  ('одолж', 'долже'): [['н'], [1]],
#  ('долже', 'олжен'): [['и'], [1]],
#  ('олжен', 'лжени'): [['я'], [1]],
#  ('лжени', 'жения'): [[' '], [1]],
#  ('жения', 'ения '): [['п'], [1]],
#  ('ения ', 'ния п'): [['о'], [1]],
#  ('ния п', 'ия по'): [['л'], [1]],
#  ('ия по', 'я пол'): [['и'], [1]],
#  ('я пол', ' поли'): [['т'], [1]],
#  (' поли', 'полит'): [['и'], [1]],
#  ('полит', 'олити'): [['к'], [1]],
#  ('олити', 'литик'): [['и'], [1]],
#  ('литик', 'итики'): [[' '], [1]],
#  ('итики', 'тики '): [[' '], [1]],
#  ('тики ', 'ики  '): [['о'], [1]],
#  ('ки  о', 'и  о '): [['н'], [1]],
#  ('и  о ', '  о н'): [['е'], [1]],
#  ('  о н', ' о не'): [['п'], [1]],
#  (' о не', 'о неп'): [['р'], [1]],
#  ('о неп', ' непр'): [['е'], [1]],
#  (' непр', 'непре'): [['р'], [1]],
#  ('непре', 'епрер'): [['ы'], [1]],
#  ('епрер', 'преры'): [['в'], [1]],
#  ('преры', 'рерыв'): [['н'], [1]],
#  ('рерыв', 'ерывн'): [['о'], [1]],
#  ('ерывн', 'рывно'): [['с'], [1]],
#  ('рывно', 'ывнос'): [['т'], [1]],
#  ('ывнос', 'вност'): [['и'], [1]],
#  ('вност', 'ности'): [[' '], [1]],
#  ('ости ', 'сти п'): [['р'], [1]],
#  ('сти п', 'ти пр'): [['о'], [1]],
#  ('ти пр', 'и про'): [['ф'], [1]],
#  ('и про', ' проф'): [['е'], [1]],
#  (' проф', 'профе'): [['с'], [1]],
#  ('профе', 'рофес'): [['с'], [1]],
#  ('рофес', 'офесс'): [['и'], [1]],
#  ('офесс', 'фесси'): [['о'], [1]],
#  ('фесси', 'ессио'): [['н'], [1]],
#  ('ессио', 'ссион'): [['а'], [1]],
#  ('ссион', 'сиона'): [['л'], [1]],
#  ('сиона', 'ионал'): [['ь'], [1]],
#  ('ионал', 'ональ'): [['н'], [1]],
#  ('ональ', 'нальн'): [['о'], [1]],
#  ('нальн', 'ально'): [['г'], [1]],
#  ('ально', 'льног'): [['о'], [1]],
#  ('льног', 'ьного'): [[' '], [2]],
#  ('ьного', 'ного '): [['и', 'п'], [1, 2]],
#  ('ного ', 'ого и'): [[' '], [1]],
#  ('ого и', 'го и '): [['о'], [1]],
#  ('го и ', 'о и о'): [['б'], [1]],
#  ('о и о', ' и об'): [['р'], [1]],
#  (' и об', 'и обр'): [['а'], [1]],
#  ('и обр', ' обра'): [['з'], [1]],
#  (' обра', 'образ'): [['о'], [1]],
#  ('образ', 'бразо'): [['в'], [1]],
#  ('бразо', 'разов'): [['а'], [1]],
#  ('разов', 'азова'): [['т'], [1]],
#  ('азова', 'зоват'): [['е'], [1]],
#  ('зоват', 'овате'): [['л'], [2]],
#  ('овате', 'вател'): [['ь', 'и'], [2, 3]],
#  ('вател', 'атель'): [['н', ' '], [1, 2]],
#  ('атель', 'тельн'): [['о'], [1]],
#  ('тельн', 'ельно'): [['г'], [1]],
#  ('ельно', 'льног'): [['о'], [1]],
#  ('ного ', 'ого п'): [['р'], [1]],
#  ('ого п', 'го пр'): [['о'], [1]],
#  ('го пр', 'о про'): [['с'], [1]],
#  ('о про', ' прос'): [['т'], [1]],
#  (' прос', 'прост'): [['р'], [1]],
#  ('прост', 'ростр'): [['а'], [1]],
#  ('ростр', 'остра'): [['н'], [1]],
#  ('остра', 'стран'): [['с'], [1]],
#  ('стран', 'транс'): [['т'], [1]],
#  ('транс', 'ранст'): [['в'], [1]],
#  ('ранст', 'анств'): [['__END__'], [1]],
#  ('встро', 'строи'): [['т'], [1]],
#  ('строи', 'троит'): [['ь'], [1]],
#  ('троит', 'роить'): [[' '], [1]],
#  ('роить', 'оить '): [['н'], [1]],
#  ('оить ', 'ить н'): [['о'], [1]],
#  ('ить н', 'ть но'): [['в'], [1]],
#  ('ть но', 'ь нов'): [['у'], [1]],
#  ('ь нов', ' нову'): [['ю'], [1]],
#  (' нову', 'новую'): [[' '], [1]],
#  ('новую', 'овую '): [['и'], [1]],
#  ('овую ', 'вую и'): [['н'], [1]],
#  ('вую и', 'ую ин'): [['ф'], [1]],
#  ('ую ин', 'ю инф'): [['о'], [1]],
#  ('ю инф', ' инфо'): [['р'], [1]],
#  (' инфо', 'инфор'): [['м'], [1]],
#  ('инфор', 'нформ'): [['а'], [1]],
#  ('нформ', 'форма'): [['ц'], [1]],
#  ('форма', 'ормац'): [['и'], [1]],
#  ('ормац', 'рмаци'): [['ю'], [1]],
#  ('рмаци', 'мацию'): [[' '], [1]],
#  ('мацию', 'ацию '): [['в'], [1]],
#  ('ацию ', 'цию в'): [[' '], [1]],
#  ('цию в', 'ию в '): [['п'], [1]],
#  ('ию в ', 'ю в п'): [['р'], [1]],
#  ('ю в п', ' в пр'): [['о'], [1]],
#  ('филь ', 'иль  '): [['т'], [1]],
#  ('иль  ', 'ль  т'): [['е'], [1]],
#  ('ль  т', 'ь  те'): [['п'], [1]],
#  ('ь  те', '  теп'): [['е'], [1]],
#  ('  теп', ' тепе'): [['р'], [1]],
#  (' тепе', 'тепер'): [['ь'], [1]],
#  ('тепер', 'еперь'): [[' '], [1]],
#  ('еперь', 'перь '): [['м'], [1]],
#  ('перь ', 'ерь м'): [['о'], [1]],
#  ('ерь м', 'рь мо'): [['ж'], [1]],
#  ('рь мо', 'ь мож'): [['н'], [1]],
#  ('ь мож', ' можн'): [['о'], [1]],
#  (' можн', 'можно'): [[' '], [2]],
#  ('можно', 'ожно '): [['н'], [2]],
#  ('ожно ', 'жно н'): [['а'], [2]],
#  ('жно н', 'но на'): [['ж', 'у'], [1, 2]],
#  ('но на', 'о наж'): [['а'], [1]],
#  ('о наж', ' нажа'): [['в'], [1]],
#  (' нажа', 'нажав'): [[' '], [1]],
#  ('нажав', 'ажав '): [['т'], [1]],
#  ('ажав ', 'жав т'): [['о'], [1]],
#  ('жав т', 'ав то'): [['л'], [1]],
#  ('ав то', 'в тол'): [['ь'], [1]],
#  ('в тол', ' толь'): [['к'], [1]],
#  (' толь', 'тольк'): [['о'], [1]],
#  ('тольк', 'олько'): [[' '], [1]],
#  ('олько', 'лько '): [['о'], [1]],
#  ('лько ', 'ько о'): [['д'], [1]],
#  ('ько о', 'ко од'): [['н'], [1]],
#  ('ко од', 'о одн'): [['у'], [1]],
#  ('о одн', ' одну'): [[' '], [1]],
#  (' одну', 'одну '): [['к'], [1]],
#  ('одну ', 'дну к'): [['н'], [1]],
#  ('дну к', 'ну кн'): [['о'], [1]],
#  ('ну кн', 'у кно'): [['п'], [1]],
#  ('у кно', ' кноп'): [['к'], [1]],
#  ('кнопк', 'нопку'): [[' '], [1]],
#  ('нопку', 'опку '): [['с'], [1]],
#  ('опку ', 'пку с'): [[' '], [1]],
#  ('пку с', 'ку с '): [['п'], [1]],
#  ('ку с ', 'у с п'): [['о'], [1]],
#  ('у с п', ' с по'): [['м'], [1]],
#  (' с по', 'с пом'): [['о'], [1]],
#  ('с пом', ' помо'): [['щ'], [1]],
#  (' помо', 'помощ'): [['ь'], [1]],
#  ('помощ', 'омощь'): [['ю'], [1]],
#  ('омощь', 'мощью'): [[' '], [1]],
#  ('мощью', 'ощью '): [['о'], [1]],
#  ('ощью ', 'щью о'): [['н'], [1]],
#  ('щью о', 'ью он'): [['л'], [1]],
#  ('ью он', 'ю онл'): [['а'], [1]],
#  ('ю онл', ' онла'): [['й'], [1]],
#  ('нлайн', 'лайнв'): [['и'], [1]],
#  ('лайнв', 'айнви'): [['д'], [1]],
#  ('айнви', 'йнвид'): [['ж'], [1]],
#  ('йнвид', 'нвидж'): [['е'], [1]],
#  ('нвидж', 'видже'): [['т'], [1]],
#  ('видже', 'иджет'): [['а'], [1]],
#  ('иджет', 'джета'): [['__END__'], [1]],
#  ('уже  ', 'же  у'): [['н'], [1]],
#  ('же  у', 'е  ун'): [['и'], [1]],
#  ('е  ун', '  уни'): [['в'], [1]],
#  ('  уни', ' унив'): [['е'], [1]],
#  ('етов ', 'тов у'): [['с'], [1]],
#  ('тов у', 'ов ус'): [['т'], [1]],
#  ('ов ус', 'в уст'): [['а'], [1]],
#  ('в уст', ' уста'): [['н'], [1]],
#  (' уста', 'устан'): [['о'], [1]],
#  ('устан', 'стано'): [['в'], [1]],
#  ('стано', 'танов'): [['и'], [1]],
#  ('танов', 'анови'): [['л'], [1]],
#  ('анови', 'новил'): [['и'], [1]],
#  ('новил', 'овили'): [[' '], [1]],
#  ('овили', 'вили '): [['н'], [1]],
#  ('вили ', 'или н'): [['а'], [1]],
#  ('или н', 'ли на'): [[' '], [1]],
#  ('ли на', 'и на '): [['с'], [1]],
#  ('и на ', ' на с'): [['в'], [1]],
#  (' на с', 'на св'): [['о'], [1]],
#  ('на св', 'а сво'): [['и'], [1]],
#  ('а сво', ' свои'): [['х'], [1]],
#  (' свои', 'своих'): [[' '], [1]],
#  ('своих', 'воих '): [['с'], [1]],
#  ('воих ', 'оих с'): [['а'], [1]],
#  ('оих с', 'их са'): [['й'], [1]],
#  ('их са', 'х сай'): [['т'], [1]],
#  ('х сай', ' сайт'): [['а'], [1]],
#  (' сайт', 'сайта'): [['х'], [1]],
#  ('сайта', 'айтах'): [[' '], [1]],
#  ('айтах', 'йтах '): [['ф'], [1]],
#  ('йтах ', 'тах ф'): [['у'], [1]],
#  ('тах ф', 'ах фу'): [['н'], [1]],
#  ('ах фу', 'х фун'): [['к'], [1]],
#  ('х фун', ' функ'): [['ц'], [1]],
#  (' функ', 'функц'): [['и'], [1]],
#  ('функц', 'ункци'): [['ю'], [1]],
#  ('ункци', 'нкцию'): [[' '], [1]],
#  ('нкцию', 'кцию '): [['м'], [1]],
#  ('кцию ', 'цию м'): [['г'], [1]],
#  ('цию м', 'ию мг'): [['н'], [1]],
#  ('ию мг', 'ю мгн'): [['о'], [1]],
#  ('ю мгн', ' мгно'): [['в'], [1]],
#  (' мгно', 'мгнов'): [['е'], [1]],
#  ('мгнов', 'гнове'): [['н'], [1]],
#  ('гнове', 'новен'): [['н'], [1]],
#  ('новен', 'овенн'): [['о'], [1]],
#  ('овенн', 'венно'): [['г'], [1]],
#  ('венно', 'енног'): [['о'], [1]],
#  ('енног', 'нного'): [[' '], [1]],
#  ('нного', 'ного '): [['д'], [1]],
#  ('ного ', 'ого д'): [['о'], [1]],
#  ('ого д', 'го до'): [['б'], [1]],
#  ('го до', 'о доб'): [['а'], [1]],
#  ('о доб', ' доба'): [['в'], [1]],
#  ('обавл', 'бавле'): [['н'], [1]],
#  ('бавле', 'авлен'): [['и'], [1]],
#  ('авлен', 'влени'): [['я'], [1]],
#  ('влени', 'ления'): [[' '], [1]],
#  ('ления', 'ения '): [['с'], [1]],
#  ('ения ', 'ния с'): [['т'], [1]],
#  ('ния с', 'ия ст'): [['е'], [1]],
#  ('ия ст', 'я сте'): [['п'], [1]],
#  ('я сте', ' степ'): [['е'], [1]],
#  (' степ', 'степе'): [['н'], [1]],
#  ('степе', 'тепен'): [['е'], [1]],
#  ('тепен', 'епене'): [['й'], [1]],
#  ('епене', 'пеней'): [[' '], [1]],
#  ('пеней', 'еней '): [['в'], [1]],
#  ('еней ', 'ней в'): [[' '], [1]],
#  ('ней в', 'ей в '): [['п'], [1]],
#  ('ей в ', 'й в п'): [['о'], [1]],
#  ('й в п', ' в по'): [['р'], [1]],
#  (' в по', 'в пор'): [['т'], [1]],
#  ('в пор', ' порт'): [['ф'], [1]],
#  (' порт', 'портф'): [['о'], [1]],
#  ('портф', 'ортфо'): [['л'], [1]],
#  ('ортфо', 'ртфол'): [['и'], [1]],
#  ('ртфол', 'тфоли'): [['о'], [1]],
#  ('тфоли', 'фолио'): [[' '], [1]],
#  ('фолио', 'олио '): [['__END__'], [1]],
#  ('среди', 'реди '): [['н'], [1]],
#  ('реди ', 'еди н'): [['и'], [1]],
#  ('еди н', 'ди ни'): [['х'], [1]],
#  ('ди ни', 'и них'): [[' '], [1]],
#  ('и них', ' них '): [['у'], [1]],
#  (' них ', 'них у'): [['н'], [1]],
#  ('них у', 'их ун'): [['и'], [1]],
#  ('их ун', 'х уни'): [['в'], [1]],
#  ('х уни', ' унив'): [['е'], [1]],
#  ('ситет', 'итет '): [['д', 'у', 'ш', 'к'], [1, 2, 3, 4]],
#  ('итет ', 'тет д'): [['ж'], [1]],
#  ('тет д', 'ет дж'): [['о'], [1]],
#  ('ет дж', 'т джо'): [['р'], [1]],
#  ('т джо', ' джор'): [['д'], [1]],
#  (' джор', 'джорд'): [['ж'], [1]],
#  ('джорд', 'жордж'): [['а'], [1]],
#  ('жордж', 'орджа'): [[' '], [1]],
#  ('орджа', 'рджа '): [['в'], [1]],
#  ('рджа ', 'джа в'): [['а'], [1]],
#  ('джа в', 'жа ва'): [['ш'], [1]],
#  ('жа ва', 'а ваш'): [['и'], [1]],
#  ('а ваш', ' ваши'): [['н'], [1]],
#  (' ваши', 'вашин'): [['г'], [1]],
#  ('вашин', 'ашинг'): [['т'], [1]],
#  ('ашинг', 'шингт'): [['о'], [1]],
#  ('шингт', 'ингто'): [['н'], [1]],
#  ('ингто', 'нгтон'): [['а'], [1]],
#  ('нгтон', 'гтона'): [[' '], [1]],
#  ('гтона', 'тона '): [['к'], [1]],
#  ('тона ', 'она к'): [['а'], [1]],
#  ('она к', 'на ка'): [['л'], [1]],
#  ('на ка', 'а кал'): [['и'], [1]],
#  ('а кал', ' кали'): [['ф'], [1]],
#  (' кали', 'калиф'): [['о'], [1]],
#  ('калиф', 'алифо'): [['р'], [1]],
#  ('алифо', 'лифор'): [['н'], [1]],
#  ('лифор', 'ифорн'): [['и'], [1]],
#  ('ифорн', 'форни'): [['й'], [1]],
#  ('форни', 'орний'): [['с'], [1]],
#  ('орний', 'рнийс'): [['к'], [1]],
#  ('рнийс', 'нийск'): [['и'], [1]],
#  ('нийск', 'ийски'): [['й'], [1]],
#  ('ийски', 'йский'): [[' '], [1]],
#  ('йский', 'ский '): [['у'], [1]],
#  ('ский ', 'кий у'): [['н'], [1]],
#  ('кий у', 'ий ун'): [['и'], [1]],
#  ('ий ун', 'й уни'): [['в'], [1]],
#  ('й уни', ' унив'): [['е'], [1]],
#  ('итет ', 'тет у'): [['н'], [1]],
#  ('тет у', 'ет ун'): [['и'], [1]],
#  ('ет ун', 'т уни'): [['в'], [1]],
#  ('т уни', ' унив'): [['е'], [1]],
#  ('итет ', 'тет ш'): [['т'], [1]],
#  ('тет ш', 'ет шт'): [['а'], [1]],
#  ('ет шт', 'т шта'): [['т'], [1]],
#  ('т шта', ' штат'): [['а'], [1]],
#  (' штат', 'штата'): [[' '], [1]],
#  ('штата', 'тата '): [['а'], [1]],
#  ('тата ', 'ата а'): [['р'], [1]],
#  ('ата а', 'та ар'): [['и'], [1]],
#  ('та ар', 'а ари'): [['з'], [1]],
#  ('а ари', ' ариз'): [['о'], [1]],
#  (' ариз', 'аризо'): [['н'], [1]],
#  ('аризо', 'ризон'): [['а'], [1]],
#  ('ризон', 'изона'): [[' '], [1]],
#  ('изона', 'зона '): [['у'], [1]],
#  ('зона ', 'она у'): [['н'], [1]],
#  ('она у', 'на ун'): [['и'], [1]],
#  ('на ун', 'а уни'): [['в'], [1]],
#  ('а уни', ' унив'): [['е'], [1]],
#  ('итет ', 'тет к'): [['е'], [1]],
#  ('тет к', 'ет ке'): [['й'], [1]],
#  ('ет ке', 'т кей'): [['о'], [1]],
#  ('т кей', ' кейо'): [[' '], [1]],
#  (' кейо', 'кейо '): [['к'], [1]],
#  ('кейо ', 'ейо к'): [['е'], [1]],
#  ('ейо к', 'йо ке'): [['м'], [1]],
#  ('йо ке', 'о кем'): [['б'], [1]],
#  ('о кем', ' кемб'): [['р'], [1]],
#  (' кемб', 'кембр'): [['и'], [1]],
#  ('кембр', 'ембри'): [['д'], [1]],
#  ('ембри', 'мбрид'): [['ж'], [1]],
#  ('мбрид', 'бридж'): [['а'], [1]],
#  ('бридж', 'риджа'): [[' '], [1]],
#  ('риджа', 'иджа '): [['м'], [1]],
#  ('иджа ', 'джа м'): [['е'], [1]],
#  ('джа м', 'жа ме'): [['л'], [1]],
#  ('жа ме', 'а мел'): [['ь'], [1]],
#  ('а мел', ' мель'): [['б'], [1]],
#  (' мель', 'мельб'): [['у'], [1]],
#  ('мельб', 'ельбу'): [['р'], [1]],
#  ('ельбу', 'льбур'): [['н'], [1]],
#  ('льбур', 'ьбурн'): [['а'], [1]],
#  ('ьбурн', 'бурна'): [[' '], [1]],
#  ('бурна', 'урна '): [['и'], [1]],
#  ('урна ', 'рна и'): [[' '], [1]],
#  ('рна и', 'на и '): [['п'], [1]],
#  ('на и ', 'а и п'): [['р'], [1]],
#  ('а и п', ' и пр'): [['о'], [1]],
#  (' и пр', 'и про'): [['ч'], [1]],
#  ('и про', ' проч'): [['__END__'], [1]],
#  ('также', 'акже '): [['п'], [1]],
#  ('акже ', 'кже п'): [['а'], [1]],
#  ('кже п', 'же па'): [['р'], [1]],
#  ('же па', 'е пар'): [['т'], [1]],
#  ('е пар', ' парт'): [['н'], [1]],
#  (' парт', 'партн'): [['е'], [1]],
#  ('партн', 'артне'): [['р'], [1]],
#  ('артне', 'ртнер'): [['а'], [1]],
#  ('ртнер', 'тнера'): [['м'], [1]],
#  ('тнера', 'нерам'): [['и'], [1]],
#  ('нерам', 'ерами'): [[' '], [1]],
#  ('ерами', 'рами '): [[' '], [1]],
#  ('рами ', 'ами  '): [['в'], [1]],
#  ('ами  ', 'ми  в'): [['ы'], [1]],
#  ('ми  в', 'и  вы'): [['с'], [1]],
#  ('и  вы', '  выс'): [['т'], [1]],
#  ('  выс', ' выст'): [['у'], [1]],
#  (' выст', 'высту'): [['п'], [1]],
#  ('высту', 'ыступ'): [['и'], [1]],
#  ('ыступ', 'ступи'): [['л'], [1]],
#  ('ступи', 'тупил'): [['и'], [1]],
#  ('тупил', 'упили'): [[' '], [1]],
#  ('упили', 'пили '): [['т'], [1]],
#  ('пили ', 'или т'): [['а'], [1]],
#  ('или т', 'ли та'): [['к'], [1]],
#  ('ли та', 'и так'): [['и'], [1]],
#  ('и так', ' таки'): [['е'], [1]],
#  (' таки', 'такие'): [[' '], [1]],
#  ('такие', 'акие '): [['м'], [1]],
#  ('акие ', 'кие м'): [['о'], [1]],
#  ('кие м', 'ие мо'): [['о'], [1]],
#  ('ие мо', 'е моо'): [['с'], [1]],
#  ('е моо', ' моос'): [['п'], [1]],
#  (' моос', 'моосп'): [['л'], [1]],
#  ('моосп', 'ооспл'): [['а'], [1]],
#  ('ооспл', 'оспла'): [['т'], [1]],
#  ('оспла', 'сплат'): [['ф'], [1]],
#  ('сплат', 'платф'): [['о'], [1]],
#  ('платф', 'латфо'): [['р'], [1]],
#  ('латфо', 'атфор'): [['м'], [1]],
#  ('атфор', 'тформ'): [['ы'], [1]],
#  ('тформ', 'формы'): [[' '], [1]],
#  ('формы', 'ормы '): [['к'], [1]],
#  ('ормы ', 'рмы к'): [['а'], [1]],
#  ('рмы к', 'мы ка'): [['к'], [1]],
#  ('мы ка', 'ы как'): [[' '], [1]],
#  ('ы как', ' как '): [[' '], [1]],
#  (' как ', 'как  '): [[' '], [1]],
#  ('как  ', 'ак   '): [[' '], [1]],
#  ('ак   ', 'к    '): [[' '], [1]],
#  ('к    ', '     '): [['и'], [1]],
#  ('     ', '    и'): [[' '], [1]],
#  ('    и', '   и '): [['б'], [1]],
#  ('   и ', '  и б'): [['о'], [1]],
#  ('  и б', ' и бо'): [['л'], [1]],
#  (' и бо', 'и бол'): [['ь'], [1]],
#  ('и бол', ' боль'): [['ш'], [1]],
#  (' боль', 'больш'): [['е'], [2]],
#  ('больш', 'ольше'): [[' ', '__END__'], [1, 2]],
#  ('ольше', 'льше '): [[' '], [1]],
#  ('льше ', 'ьше  '): [['д'], [1]],
#  ('ьше  ', 'ше  д'): [['р'], [1]],
#  ('ше  д', 'е  др'): [['у'], [1]],
#  ('е  др', '  дру'): [['г'], [1]],
#  ('  дру', ' друг'): [['и'], [1]],
#  (' друг', 'други'): [['х'], [1]],
#  ('други', 'ругих'): [[' '], [1]],
#  ('ругих', 'угих '): [['к'], [1]],
#  ('угих ', 'гих к'): [['у'], [1]],
#  ('гих к', 'их ку'): [['р'], [1]],
#  ('их ку', 'х кур'): [['с'], [1]],
#  ('х кур', ' курс'): [['о'], [1]],
#  (' курс', 'курсо'): [['в'], [1]],
#  ('в  по', '  пол'): [['ь'], [1]],
#  ('  пол', ' поль'): [['з'], [1]],
#  (' поль', 'польз'): [['о'], [1]],
#  ('польз', 'ользо'): [['в'], [1]],
#  ('ользо', 'льзов'): [['а'], [1]],
#  ('льзов', 'ьзова'): [['т'], [1]],
#  ('ьзова', 'зоват'): [['е'], [1]],
#  ('вател', 'атели'): [[' '], [1]],
#  ('атели', 'тели '): [['т'], [1]],
#  ('тели ', 'ели т'): [['о'], [1]],
#  ('ели т', 'ли то'): [['ж'], [1]],
#  ('ли то', 'и тож'): [['е'], [1]],
#  ('и тож', ' тоже'): [[' '], [1]],
#  (' тоже', 'тоже '): [['п'], [1]],
#  ('тоже ', 'оже п'): [['о'], [1]],
#  ('оже п', 'же по'): [['л'], [1]],
#  ('же по', 'е пол'): [['у'], [1]],
#  ('е пол', ' полу'): [['ч'], [1]],
#  (' полу', 'получ'): [['а'], [1]],
#  ('получ', 'олуча'): [['ю'], [1]],
#  ('олуча', 'лучаю'): [['т'], [1]],
#  ('лучаю', 'учают'): [[' '], [1]],
#  ('учают', 'чают '): [['с'], [1]],
#  ('чают ', 'ают с'): [['е'], [1]],
#  ('ают с', 'ют се'): [['р'], [1]],
#  ('ют се', 'т сер'): [['т'], [1]],
#  ('т сер', ' серт'): [['и'], [1]],
#  ('каты ', 'аты  '): [['т'], [1]],
#  ('аты  ', 'ты  т'): [['а'], [1]],
#  ('ты  т', 'ы  та'): [['к'], [1]],
#  ('ы  та', '  так'): [[' '], [1]],
#  ('  так', ' так '): [['н'], [1]],
#  (' так ', 'так н'): [['а'], [1]],
#  ('так н', 'ак на'): [['п'], [1]],
#  ('ак на', 'к нап'): [['р'], [1]],
#  ('к нап', ' напр'): [['и'], [1]],
#  (' напр', 'напри'): [['м'], [1]],
#  ('напри', 'априм'): [['е'], [1]],
#  ('априм', 'приме'): [['р'], [1]],
#  ('приме', 'ример'): [[' '], [1]],
#  ('ример', 'имер '): [['е'], [1]],
#  ('имер ', 'мер е'): [['с'], [1]],
#  ('мер е', 'ер ес'): [['т'], [1]],
#  ('ер ес', 'р ест'): [['ь'], [1]],
#  ('р ест', ' есть'): [[' '], [1]],
#  (' есть', 'есть '): [['с'], [1]],
#  ('есть ', 'сть с'): [['е'], [1]],
#  ('сть с', 'ть се'): [['р'], [1]],
#  ('ть се', 'ь сер'): [['т'], [1]],
#  ('каты ', 'аты с'): [['п'], [1]],
#  ('аты с', 'ты сп'): [['е'], [1]],
#  ('ты сп', 'ы спе'): [['ц'], [1]],
#  ('ы спе', ' спец'): [['и'], [1]],
#  (' спец', 'специ'): [['а'], [2]],
#  ('специ', 'пециа'): [['л'], [2]],
#  ('пециа', 'ециал'): [['и', 'ь'], [1, 2]],
#  ('ециал', 'циали'): [['с'], [1]],
#  ('циали', 'иалис'): [['т'], [1]],
#  ('иалис', 'алист'): [['о'], [1]],
#  ('алист', 'листо'): [['в'], [1]],
#  ('листо', 'истов'): [[' '], [1]],
#  ('истов', 'стов '): [['в'], [1]],
#  ('стов ', 'тов в'): [[' '], [1]],
#  ('тов в', 'ов в '): [['о'], [1]],
#  ('ов в ', 'в в о'): [['б'], [1]],
#  ('в в о', ' в об'): [['л'], [1]],
#  (' в об', 'в обл'): [['а'], [1]],
#  ('в обл', ' обла'): [['с'], [1]],
#  (' обла', 'облас'): [['т'], [1]],
#  ('облас', 'бласт'): [['и'], [1]],
#  ('бласт', 'ласти'): [[' '], [1]],
#  ('ласти', 'асти '): [['м'], [1]],
#  ('асти ', 'сти м'): [['е'], [1]],
#  ('сти м', 'ти ме'): [['д'], [1]],
#  ('ти ме', 'и мед'): [['и'], [1]],
#  ('и мед', ' меди'): [['ц'], [1]],
#  (' меди', 'медиц'): [['и'], [1]],
#  ('медиц', 'едици'): [['н'], [1]],
#  ('едици', 'дицин'): [['с'], [1]],
#  ('дицин', 'ицинс'): [['к'], [1]],
#  ('ицинс', 'цинск'): [['о'], [1]],
#  ('цинск', 'инско'): [['г'], [1]],
#  ('инско', 'нског'): [['о'], [1]],
#  ('нског', 'ского'): [[' '], [1]],
#  ('ского', 'кого '): [['о'], [1]],
#  ('кого ', 'ого о'): [['б'], [1]],
#  ('ого о', 'го об'): [['о'], [1]],
#  ('го об', 'о обо'): [['р'], [1]],
#  ('о обо', ' обор'): [['у'], [1]],
#  (' обор', 'обору'): [['д'], [1]],
#  ('обору', 'боруд'): [['о'], [1]],
#  ('боруд', 'орудо'): [['в'], [1]],
#  ('орудо', 'рудов'): [['а'], [1]],
#  ('рудов', 'удова'): [['н'], [1]],
#  ('удова', 'дован'): [['и'], [1]],
#  ('дован', 'овани'): [['я'], [1]],
#  ('овани', 'вания'): [[' '], [1]],
#  ('вания', 'ания '): [['с'], [1]],
#  ('ания ', 'ния с'): [['е'], [1]],
#  ('ния с', 'ия се'): [['р'], [1]],
#  ('ия се', 'я сер'): [['т'], [1]],
#  ('я сер', ' серт'): [['и'], [1]],
#  ('каты ', 'аты п'): [['р'], [1]],
#  ('аты п', 'ты пр'): [['и'], [1]],
#  ('ты пр', 'ы при'): [[' '], [1]],
#  ('ы при', ' при '): [['о'], [1]],
#  (' при ', 'при о'): [['б'], [1]],
#  ('при о', 'ри об'): [['у'], [1]],
#  ('ри об', 'и обу'): [['ч'], [1]],
#  ('и обу', ' обуч'): [['е'], [1]],
#  (' обуч', 'обуче'): [['н'], [1]],
#  ('обуче', 'бучен'): [['и'], [1]],
#  ('бучен', 'учени'): [['и'], [1]],
#  ('учени', 'чении'): [[' '], [1]],
#  ('чении', 'ении '): [['п'], [1]],
#  ('ении ', 'нии п'): [['о'], [1]],
#  ('нии п', 'ии по'): [[' '], [1]],
#  ('ии по', 'и по '): [['с'], [1]],
#  ('и по ', ' по с'): [['п'], [1]],
#  (' по с', 'по сп'): [['е'], [1]],
#  ('по сп', 'о спе'): [['ц'], [1]],
#  ('о спе', ' спец'): [['и'], [1]],
#  ('ециал', 'циаль'): [['н'], [1]],
#  ('циаль', 'иальн'): [['о'], [1]],
#  ('иальн', 'ально'): [['с'], [1]],
#  ('ально', 'льнос'): [['т'], [1]],
#  ('льнос', 'ьност'): [['я'], [1]],
#  ('ьност', 'ностя'): [['м'], [1]],
#  ('ностя', 'остям'): [[' '], [1]],
#  ('остям', 'стям '): [['м'], [1]],
#  ('стям ', 'тям м'): [['е'], [1]],
#  ('тям м', 'ям ме'): [['р'], [1]],
#  ('ям ме', 'м мер'): [['ч'], [1]],
#  ('м мер', ' мерч'): [['е'], [1]],
#  (' мерч', 'мерче'): [['н'], [1]],
#  ('мерче', 'ерчен'): [['д'], [1]],
#  ('ерчен', 'рченд'): [['а'], [1]],
#  ('рченд', 'ченда'): [['й'], [1]],
#  ('ченда', 'ендай'): [['з'], [1]],
#  ('ендай', 'ндайз'): [['е'], [1]],
#  ('ндайз', 'дайзе'): [['р'], [1]],
#  ('дайзе', 'айзер'): [[' '], [1]],
#  ('айзер', 'йзер '): [['и'], [1]],
#  ('йзер ', 'зер и'): [[' '], [1]],
#  ('зер и', 'ер и '): [['с'], [1]],
#  ('ер и ', 'р и с'): [['у'], [1]],
#  ('р и с', ' и су'): [['п'], [1]],
#  (' и су', 'и суп'): [['е'], [1]],
#  ('и суп', ' супе'): [['р'], [1]],
#  (' супе', 'супер'): [['в'], [1]],
#  ('супер', 'уперв'): [['а'], [1]],
#  ('уперв', 'перва'): [['й'], [1]],
#  ('перва', 'ервай'): [['з'], [1]],
#  ('ервай', 'рвайз'): [['е'], [1]],
#  ('рвайз', 'вайзе'): [['р'], [1]],
#  ('вайзе', 'айзер'): [['__END__'], [1]],
#  ('чем д', 'ем да'): [['л'], [1]],
#  ('ем да', 'м дал'): [['ь'], [1]],
#  ('м дал', ' даль'): [['ш'], [1]],
#  (' даль', 'дальш'): [['е'], [1]],
#  ('дальш', 'альше'): [[' '], [1]],
#  ('альше', 'льше '): [['т'], [1]],
#  ('льше ', 'ьше т'): [['е'], [1]],
#  ('ьше т', 'ше те'): [['м'], [1]],
#  ('ше те', 'е тем'): [[' '], [1]],
#  ('е тем', ' тем '): [['т'], [1]],
#  (' тем ', 'тем т'): [['а'], [1]],
#  ('тем т', 'ем та'): [['к'], [1]],
#  ('ем та', 'м так'): [['и'], [1]],
#  ('м так', ' таки'): [['х'], [1]],
#  (' таки', 'таких'): [[' '], [1]],
#  ('таких', 'аких '): [['с'], [1]],
#  ('аких ', 'ких с'): [['е'], [1]],
#  ('ких с', 'их се'): [['р'], [1]],
#  ('их се', 'х сер'): [['т'], [1]],
#  ('х сер', ' серт'): [['и'], [1]],
#  ('фикат', 'икато'): [['в'], [1]],
#  ('икато', 'катов'): [[' '], [1]],
#  ('катов', 'атов '): [['б'], [1]],
#  ('атов ', 'тов б'): [['о'], [1]],
#  ('тов б', 'ов бо'): [['л'], [1]],
#  ('ов бо', 'в бол'): [['ь'], [1]],
#  ('в бол', ' боль'): [['ш'], [1]],
#  ('и в н', ' в на'): [['ш'], [1]],
#  (' в на', 'в наш'): [['и'], [1]],
#  ('в наш', ' наши'): [[' '], [1]],
#  (' наши', 'наши '): [['п'], [1]],
#  ('наши ', 'аши п'): [['л'], [1]],
#  ('аши п', 'ши пл'): [['а'], [1]],
#  ('ши пл', 'и пла'): [['н'], [1]],
#  ('и пла', ' план'): [['ы'], [1]],
#  (' план', 'планы'): [[' '], [1]],
#  ('планы', 'ланы '): [['в'], [1]],
#  ('ланы ', 'аны в'): [['х'], [1]],
#  ('аны в', 'ны вх'): [['о'], [1]],
#  ('ны вх', 'ы вхо'): [['д'], [1]],
#  ('ы вхо', ' вход'): [['и'], [1]],
#  (' вход', 'входи'): [['т'], [1]],
#  ('входи', 'ходит'): [[' '], [1]],
#  ('ходит', 'одит '): [['п'], [1]],
#  ('одит ', 'дит п'): [['р'], [1]],
#  ('дит п', 'ит пр'): [['и'], [1]],
#  ('ит пр', 'т при'): [['к'], [1]],
#  ('т при', ' прик'): [['р'], [1]],
#  (' прик', 'прикр'): [['у'], [1]],
#  ('прикр', 'рикру'): [['т'], [1]],
#  ('рикру', 'икрут'): [['к'], [1]],
#  ('икрут', 'крутк'): [['а'], [1]],
#  ('крутк', 'рутка'): [[' '], [1]],
#  ('рутка', 'утка '): [['и'], [1]],
#  ('утка ', 'тка и'): [['х'], [1]],
#  ('тка и', 'ка их'): [[' '], [1]],
#  ('ка их', 'а их '): [['в'], [1]],
#  ('а их ', ' их в'): [[' '], [1]],
#  (' их в', 'их в '): [[' '], [1]],
#  ('их в ', 'х в  '): [[' '], [1]],
#  ('х в  ', ' в   '): [['с'], [1]],
#  (' в   ', 'в   с'): [['о'], [1]],
#  ('в   с', '   со'): [['о'], [1]],
#  ('   со', '  соо'): [['б'], [1]],
#  ('  соо', ' сооб'): [['щ'], [1]],
#  (' сооб', 'сообщ'): [['а'], [1]],
#  ('сообщ', 'ообща'): [['е'], [1]],
#  ('ообща', 'общае'): [['т'], [1]],
#  ('общае', 'бщает'): [[' '], [1]],
#  ('бщает', 'щает '): [['с'], [1]],
#  ('щает ', 'ает с'): [['о'], [1]],
#  ('ает с', 'ет со'): [['о'], [1]],
#  ('ет со', 'т соо'): [['с'], [1]],
#  ('т соо', ' соос'): [['н'], [1]],
#  (' соос', 'соосн'): [['о'], [1]],
#  ('соосн', 'оосно'): [['в'], [1]],
#  ('оосно', 'основ'): [['а'], [1]],
#  ('основ', 'снова'): [['т'], [1]],
#  ('снова', 'новат'): [['е'], [1]],
#  ('новат', 'овате'): [['л'], [1]],
#  ('атель', 'тель '): [[' '], [1]],
#  ('тель ', 'ель  '): [['в'], [1]],
#  ('ель  ', 'ль  в'): [['л'], [1]],
#  ('ль  в', 'ь  вл'): [['а'], [1]],
#  ('ь  вл', '  вла'): [['д'], [1]],
#  ('  вла', ' влад'): [['и'], [1]],
#  (' влад', 'влади'): [['м'], [1]],
#  ('влади', 'ладим'): [['и'], [1]],
#  ('ладим', 'адими'): [['р'], [1]],
#  ('адими', 'димир'): [[' '], [1]],
#  ('димир', 'имир '): [['щ'], [1]],
#  ('имир ', 'мир щ'): [['е'], [1]],
#  ('мир щ', 'ир ще'): [['р'], [1]],
#  ('ир ще', 'р щер'): [['б'], [1]],
#  ('р щер', ' щерб'): [['а'], [1]],
#  (' щерб', 'щерба'): [['к'], [1]],
#  ('щерба', 'ербак'): [['о'], [1]],
#  ('ербак', 'рбако'): [['в'], [1]],
#  ('рбако', 'баков'): [[' '], [1]],
#  ('баков', 'аков '): [[' '], [1]],
#  ('аков ', 'ков  '): [['о'], [1]],
#  ('ков  ', 'ов  о'): [['н'], [1]],
#  ('ов  о', 'в  он'): [['л'], [1]],
#  ('в  он', '  онл'): [['а'], [1]],
#  ('  онл', ' онла'): [['й'], [1]],
#  ('нлайн', 'лайн '): [['м'], [1]],
#  ('лайн ', 'айн м'): [['о'], [1]],
#  ('айн м', 'йн мо'): [['ж'], [1]],
#  ('йн мо', 'н мож'): [['н'], [1]],
#  ('н мож', ' можн'): [['о'], [1]],
#  ('но на', 'о нау'): [['ч'], [1]],
#  ('о нау', ' науч'): [['и'], [1]],
#  (' науч', 'научи'): [['т'], [1]],
#  ('научи', 'аучит'): [['ь'], [1]],
#  ('аучит', 'учить'): [['с'], [1]],
#  ('учить', 'читьс'): [['я'], [1]],
#  ('читьс', 'иться'): [[' '], [1]],
#  ('иться', 'ться '): [['ч'], [1]],
#  ('ться ', 'ься ч'): [['е'], [1]],
#  ('ься ч', 'ся че'): [['м'], [1]],
#  ('ся че', 'я чем'): [['у'], [1]],
#  ('я чем', ' чему'): [[' '], [1]],
#  (' чему', 'чему '): [['у'], [1]],
#  ('чему ', 'ему у'): [['г'], [1]],
#  ('ему у', 'му уг'): [['о'], [1]],
#  ('му уг', 'у уго'): [['д'], [1]],
#  ('у уго', ' угод'): [['н'], [1]],
#  (' угод', 'угодн'): [['о'], [1]],
#  ('угодн', 'годно'): [[' '], [1]],
#  ('годно', 'одно '): [['__END__'], [1]]}

# %%
''.join(chain.walk(('разра', 'азраб')))
# Out:
# 'отчики  о непрерывности профессионального и образователи тоже получают сертификаты и дипломы от онлайнвиджета'

# %%
next(TextProcessor.get_ngram_gen(['Привет, Андрей!']))
# Out:
# ['при', 'рив', 'иве', 'вет', 'ет ', 'т а', ' ан', 'анд', 'ндр', 'дре', 'рей']

# %%
class NgrammTextGenerator:

    chain: EncodedChain
    state_size: int
    ngram_size: int
    re_process: re.Pattern = re.compile(r'[^а-яА-ЯёЁ ]')

    def __init__(self,
                 state_size: int,
                 input_text: Iterable = None,
                 ngram_size: int = 3):
        self.state_size = state_size
        self.ngram_size = ngram_size
        if input_text:
            self.add_model(input_text)

    @classmethod
    def load(cls,
             state_size: int,
             ngram_size: int = 3):
        return cls(
            state_size=state_size,
            ngram_size=ngram_size)

    @classmethod
    def train(cls,
              train_text: Iterable,
              state_size: int,
              ngram_size: int = 3):
        return cls(
            input_text=train_text,
            state_size=state_size,
            ngram_size=ngram_size)

    def add_model(self, input_text: Iterable):
        train_corpus = list(TextProcessor.get_ngram_gen(input_text, self.ngram_size))
        self.chain = EncodedChain(train_corpus, self.state_size)
        logging.info(f'Add new model: {self}')

    def ngrams_split(self, sentence: str) -> List[str]:
        ngrams_list = next(TextProcessor.get_ngram_gen([sentence], self.ngram_size))
        return ngrams_list

    def ngrams_join(self, ngrams_list: List[str]) -> str:
        return ngrams_list[0][:-1] + ''.join([ngram[-1] for ngram in ngrams_list])

    def make_sentence(self, init_state: List[str], **kwargs) -> List[str]:
        tries = kwargs.get('tries', 10)
        max_words = kwargs.get('max_words', None)
        min_words = kwargs.get('min_words', None)

        for _ in range(tries):
            chars_list = self.chain.walk(tuple(init_state))
            if (max_words is not None and len(chars_list) > max_words) or (
                    min_words is not None and len(chars_list) < min_words):
                continue
            return chars_list
        return []

    def make_sentence_with_start(self, input_phrase: str, **kwargs) -> str:
        items_list = self.ngrams_split(input_phrase)
        items_count = len(items_list)

        if items_count == self.state_size:
            init_state = items_list

        elif self.state_size < items_count:
            init_state = items_list[-self.state_size:]
        else:
            return ''

        chars_list = self.make_sentence(init_state, **kwargs)
        return self.ngrams_join(items_list) + ''.join(chars_list)

    def make_sentences_for_t9(self,
                              beginning: str,
                              first_words_count: int = 1,
                              count: int = 30,
                              phrase_len: int = 5,
                              **kwargs) -> List[str]:
        phrases = set()
        for i in range(count):
            phrase = self.make_sentence_with_start(beginning, min_words=phrase_len, **kwargs)
            print(phrase)
            if phrase:
                words_list = phrase.split()
                if 1 < len(words_list) >= phrase_len:
                    phrases.add(" ".join(words_list[first_words_count:]))
        return list(phrases)

    def __repr__(self) -> str:
        return '<TextGenerator: state_size=%s, ngrams_size=%s>' % (
            self.state_size, self.ngram_size)

# %%
corpus = [row[0] for row in corpus]
len(corpus)
# Out:
# 3000

# %%
model = NgrammTextGenerator.train(train_text=corpus,
                                  state_size=3,
                                  ngram_size=5)

# %%
model.make_sentences_for_t9('нейронные сети')
# Out:
# нейронные сети к одному из супермаркета но явно помимо вышеуказанным тз
# нейронные сети из нее теперь осталось на один хват
# нейронные сети связано
# нейронные сети одновременного и тд
# нейронные сети структуру таблицы
# нейронные сети и занимаюсь уже она не изучил вот это повторно собрать нужный гаджет в области  настоящим за недовольствие и просматривать а они казалось бы две вершин в каждом новой технологическом виде переключениями о проблема  лишь владела  теперь мне найти пассивные алгоритма  видно углубившись с ограничением  заключает в себе для нового место поэтому высокого уровня где ему нужно предзаказа как верхнего уровня что ближайшем будущем
# нейронные сети  реализующие  элемента можно сказано в принцип объяснишь человека
# нейронные сети будете породил целую кучу и включены к одному человека и понятных потоком заряжаем экстернализации можно изза требование блоба
# нейронные сети насчет разную индуктивным  это достигала  тесла
# нейронные сети для параметра
# нейронные сети нужно прост     вот ведь код приложением ип
# нейронные сети дающая просьбе пользователь  давиденко вячеслав основном не все еще имеют официальных двух крупные командный дух
# нейронные сетимузыкантами и пробуем ещё один жирный  ггц кстати долго это могло бы предполагается экстрактировать его свича любого существует  возможностью скопирование сотрудник на а которые они могли себе просто игра в корень всем этим данным
# нейронные сети сна
# нейронные сети в свернулись из нашей системой корпоративной памяти единого системе
# нейронные сети на форума
# нейронные сети  зарядному условия  тогда как видим списке  появился скручиваться поисковика
# нейронные сети в каждой части там появилосьне понравится работы нескольких устройствами и не позволял хакеров
# нейронные сетимузыканта тупиковую крышку с головок  закрытия
# нейронные сети дилеров тоже должны легко заставивших обособленные
# нейронные сети замены  нагрузка на сайта удалось устройства компьютерная хотя истинноваторскую дозу лекарства хостинг                        затем инструкции
# нейронные сети билайн
# нейронные сети и до х лет всетаки   мбит
# нейронные сети остановка брейкпоинтомсрочное
# нейронные сети можно сделано правильном направления без модулей от трех  батарейки сэто опус посвящена небольшие рассуждать показательство в котором может иметь так жесткий дисплея
# нейронные сети полной или иного продукте и его структуру конвертер модель только лет филиалов поэтому здесь еще немного человек должен задать новую формула  предлагают ввести в файле  прекрасно подойдет идентификацию там где ничего о скорости второй изменяется автомобильных версий на мой взгляд это  мегабайт посвящается всяческих термоядерных итерацию плюсы компании  никого на данных проекта его частью браузере
# нейронные сети  недоумение что получен в режиме авторизацию особенно активно задать палиндром палташева от точки зрения тканями по привлечения поддержку  на вечеринка
# нейронные сети не совсем компиляции что я сделал и запускаем заголовка идет активен то процесс управляются обработки именно размер самого
# нейронные сетимузыкант стал одним из областей  частичных интерфейс у него предложения
# нейронные сети изменяторы видят работы над большинстве случае практики выяснить что предоставляют куб в массива
# ['сети замены нагрузка на сайта удалось устройства компьютерная хотя истинноваторскую дозу лекарства хостинг затем инструкции',
#  'сети насчет разную индуктивным это достигала тесла',
#  'сетимузыканта тупиковую крышку с головок закрытия',
#  'сети будете породил целую кучу и включены к одному человека и понятных потоком заряжаем экстернализации можно изза требование блоба',
#  'сети реализующие элемента можно сказано в принцип объяснишь человека',
#  'сети дающая просьбе пользователь давиденко вячеслав основном не все еще имеют официальных двух крупные командный дух',
#  'сети полной или иного продукте и его структуру конвертер модель только лет филиалов поэтому здесь еще немного человек должен задать новую формула предлагают ввести в файле прекрасно подойдет идентификацию там где ничего о скорости второй изменяется автомобильных версий на мой взгляд это мегабайт посвящается всяческих термоядерных итерацию плюсы компании никого на данных проекта его частью браузере',
#  'сети к одному из супермаркета но явно помимо вышеуказанным тз',
#  'сети из нее теперь осталось на один хват',
#  'сети и занимаюсь уже она не изучил вот это повторно собрать нужный гаджет в области настоящим за недовольствие и просматривать а они казалось бы две вершин в каждом новой технологическом виде переключениями о проблема лишь владела теперь мне найти пассивные алгоритма видно углубившись с ограничением заключает в себе для нового место поэтому высокого уровня где ему нужно предзаказа как верхнего уровня что ближайшем будущем',
#  'сети можно сделано правильном направления без модулей от трех батарейки сэто опус посвящена небольшие рассуждать показательство в котором может иметь так жесткий дисплея',
#  'сети одновременного и тд',
#  'сети и до х лет всетаки мбит',
#  'сети в свернулись из нашей системой корпоративной памяти единого системе',
#  'сетимузыкантами и пробуем ещё один жирный ггц кстати долго это могло бы предполагается экстрактировать его свича любого существует возможностью скопирование сотрудник на а которые они могли себе просто игра в корень всем этим данным',
#  'сети дилеров тоже должны легко заставивших обособленные',
#  'сети не совсем компиляции что я сделал и запускаем заголовка идет активен то процесс управляются обработки именно размер самого',
#  'сети нужно прост вот ведь код приложением ип',
#  'сети недоумение что получен в режиме авторизацию особенно активно задать палиндром палташева от точки зрения тканями по привлечения поддержку на вечеринка',
#  'сети изменяторы видят работы над большинстве случае практики выяснить что предоставляют куб в массива',
#  'сетимузыкант стал одним из областей частичных интерфейс у него предложения',
#  'сети зарядному условия тогда как видим списке появился скручиваться поисковика',
#  'сети в каждой части там появилосьне понравится работы нескольких устройствами и не позволял хакеров']

# %%
7.78 - 10.7
# Out:
# -2.919999999999999

# %%
model.chain.to_json()
