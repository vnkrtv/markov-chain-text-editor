# %%
from models import MongoStorage, PostgresStorage

# %%
from sqlalchemy import create_engine

# %%
PG_HOST = '172.17.0.2'
pg_engine = create_engine(f'postgresql+psycopg2://postgres:password@{PG_HOST}/habr', pool_recycle=3600)
pg_conn = pg_engine.connect()

# %%
import pandas as pd

posts_df = pd.read_sql("select * from posts", pg_conn)
posts_df.head(10)
# Out:
#    post_id                                              title  \
# 0   370841                    Список участников БРОНЕБОТ-2017
# 1   386081  Израильтяне объявили о разработке антивируса н...
# 2   137161  Аудит таблиц с пространственными объектами в P...
# 3    15241  Письмо из страны Советов главе компании Apple ...
# 4    20321                          Toshiba похоронит HD DVD?
# 5   142241  Оптимизация flatpages проекта на django под ми...
# 6    25401              Шрифтовое юзабилити для верстальщиков
# 7   381001  Обзор Quick Resto. Как создать и автоматизиров...
# 8    25402                 E: Весь пафос TextMate для Windows
# 9   391161  Крис Картер: X-Files, скорее всего, вернутся с...
#
#                                                 text                date  \
# 0  \nУже 29 октября в Олимпийском пройдут бои роб... 2017-09-25 17:14:00
# 1  \n\nИзраильский стартап Deep Instinct объявил ... 2015-11-02 21:17:00
# 2  В предыдущей статье был рассмотрен пример с пр... 2012-02-01 09:41:00
# 3  В этот блог я собираюсь публиковать свои анали... 2007-10-20 16:01:00
# 4  Голливуд полнится слухами о скором окончании в... 2008-02-15 15:21:00
# 5  \n\nПод катом много букв, но не беспокойтесь —... 2012-04-21 17:02:00
# 6  Иногда, работая в текстовом редакторе с моим л... 2008-05-14 21:56:00
# 7  Каждому из нас хотелось бы иметь свой бизнес. ... 2015-06-30 15:03:00
# 8  E — это уже не первый текстовый редактор для W... 2008-05-14 22:25:00
# 9  \nСъёмки были трудными\n\nФанаты «Секретных ма... 2016-02-29 01:16:00
#
#    views_count  comments_count  bookmarks_count rating author_nickname  \
# 0         5500              13                9    +10   sergeykalenik
# 1        11000               9               11     +6           SLY_G
# 2         3300               2               22     +6       pashtet51
# 3          763              15                2    –10          zboris
# 4          280               3                0     +3          Tigger
# 5         6500              50              206    +62         magic4x
# 6          938               7                5     +5      tihobrazov
# 7        13500              19               68    +12         Kuuuzya
# 8         3800              47               24    +20      dreikanter
# 9         8500              37               13     +6           SLY_G
#
#                                            habs_list  \
# 0  Блог компании ВиЭмТи Групп,Компьютерное железо...
# 1                                 Научная фантастика
# 2                                         PostgreSQL
# 3                                        IT-компании
# 4                                              Чулан
# 5                       Разработка веб-сайтов,Django
# 6                                        Типографика
# 7  Блог компании Quick Resto,Гаджеты,Компьютерное...
# 8                                               Софт
# 9                                 Научная фантастика
#
#                                            tags_list
# 0  робототехника,робототехника своими руками,diy,...
# 1                                  вирусы,антивирусы
# 2             базы данных,postgresql,картография,гис
# 3  Apple,Mac,MacOS,MacOS X for Intel,Стив Джобс,M...
# 4  видео,HD-video,видео высокой четкости,война фо...
# 5       django,django-compress,uwsgi,nginx,memcached
# 6                       шрифты,юзабилити,типографика
# 7    QuickResto,облачный сервис,автоматизация,QR box
# 8                    текстовые редакторы,программы,e
# 9                        x-files,секретные материалы

# %%
import tqdm

habs_dict = {}

for _, row in tqdm.tqdm(posts_df.iterrows()):
    for hab in row['habs_list'].split(','):
        if hab in habs_dict:
            habs_dict[hab] += 1
        else:
            habs_dict[hab] = 1
len(habs_dict), list(habs_dict.items())[:2]
# Out:
# 38443it [00:02, 13709.72it/s]
# (1589, [('Блог компании ВиЭмТи Групп', 7), ('Компьютерное железо', 804)])

# %%
tags_dict = {}

for _, row in tqdm.tqdm(posts_df.iterrows()):
    for tag in row['tags_list'].split(','):
        if tag in tags_dict:
            tags_dict[tag] += 1
        else:
            tags_dict[tag] = 1
len(tags_dict), list(tags_dict.items())[:2]
# Out:
# 38443it [00:02, 13552.72it/s]
# (59908, [('робототехника', 123), ('робототехника своими руками', 5)])

# %%
habs_list = list(habs_dict.keys())
posts_habs = []
for _, row in tqdm.tqdm(posts_df.iterrows()):
    posts_habs.append(row['habs_list'].split(','))
posts_habs[:2]
# Out:
# 38443it [00:02, 13422.52it/s]
# [['Блог компании ВиЭмТи Групп',
#   'Компьютерное железо',
#   'Робототехника',
#   'DIY или Сделай сам'],
#  ['Научная фантастика']]

# %%
class Habs2Vec:
    
    habs2code: dict
    code2hab: dict
    
    def fit(self, habs_list: list) -> None:
        self.habs2code = {hab: i for i, hab in enumerate(habs_list)}
        self.code2hab = {i: hab for i, hab in enumerate(habs_list)}
        
    def transform(self, post_habs: list) -> np.array:
        vec = np.zeros(len(self.habs2code), dtype=np.int0)
        for hab in post_habs:
            vec[self.habs2code[hab]] = 1
        return vec
    
    def encode_vec(self, vec: np.array) -> list:
        habs = []
        for i, elem in enumerate(vec):
            if elem:
                habs.append(self.code2hab[i])
        return habs
    
transformer = Habs2Vec()
transformer.fit(habs_list)
print('Habs: ', habs_list[:2] + habs_list[-2:])
vec = transformer.transform(habs_list[:2] + habs_list[-2:])
print('Binary vector: ', vec)
print('Decoded binary vector: ', transformer.encode_vec(vec))
# Out:
# Habs:  ['Блог компании ВиЭмТи Групп', 'Компьютерное железо', 'Блог компании VaM Shop', 'Блог компании Слобода']
# Binary vector:  [1 1 0 ... 0 1 1]
# Decoded binary vector:  ['Блог компании ВиЭмТи Групп', 'Компьютерное железо', 'Блог компании VaM Shop', 'Блог компании Слобода']

# %%
decoded_habs_list = [transformer.transform(habs) for habs in posts_habs]
len(decoded_habs_list), decoded_habs_list[:2]
# Out:
# (38443, [array([1, 1, 1, ..., 0, 0, 0]), array([0, 0, 0, ..., 0, 0, 0])])

# %%
from sklearn.cluster import DBSCAN

dbscan = DBSCAN()
dbscan.fit(decoded_habs_list)
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
print('Len of', dbscan.labels_, "is", len(dbscan.labels_))
print('Clusters count:', len(set(dbscan.labels_)))
# Out:
# Len of [ -1   0   1 ... 335 335  78] is 38443
# Clusters count: 704

# %%
habs_clusters = {}
for label, habs_vec in zip(dbscan.labels_, decoded_habs_list):
    if label in habs_clusters:
        habs_clusters[label].append(habs_vec)
    else:
        habs_clusters[label] = [habs_vec]
for key in habs_clusters:
    print(key, ' => ', len(habs_clusters[label]))
# Out:
# -1  =>  239
# 0  =>  239
# 1  =>  239
# 2  =>  239
# 3  =>  239
# 4  =>  239
# 5  =>  239
# 6  =>  239
# 7  =>  239
# 8  =>  239
# 9  =>  239
# 10  =>  239
# 11  =>  239
# 12  =>  239
# 13  =>  239
# 14  =>  239
# 15  =>  239
# 16  =>  239
# 17  =>  239
# 18  =>  239
# 19  =>  239
# 20  =>  239
# 21  =>  239
# 571  =>  239
# 572  =>  239
# 573  =>  239
# 574  =>  239
# 575  =>  239
# 576  =>  239
# 577  =>  239
# 578  =>  239
# 579  =>  239
# 580  =>  239
# 581  =>  239
# 582  =>  239
# 583  =>  239
# 584  =>  239
# 585  =>  239
# 586  =>  239
# 587  =>  239
# 588  =>  239
# 589  =>  239
# 590  =>  239
# 591  =>  239
# 592  =>  239
# 593  =>  239
# 594  =>  239
# 595  =>  239
# 596  =>  239
# 597  =>  239
# 598  =>  239
# 599  =>  239
# 600  =>  239
# 601  =>  239
# 602  =>  239
# 603  =>  239
# 604  =>  239
# 605  =>  239
# 606  =>  239
# 607  =>  239
# 608  =>  239
# 609  =>  239
# 610  =>  239
# 611  =>  239
# 612  =>  239
# 613  =>  239
# 614  =>  239
# 615  =>  239
# 616  =>  239
# 617  =>  239
# 618  =>  239
# 619  =>  239
# 620  =>  239
# 621  =>  239
# 622  =>  239
# 623  =>  239
# 624  =>  239
# 625  =>  239
# 626  =>  239
# 627  =>  239
# 628  =>  239
# 629  =>  239
# 630  =>  239
# 631  =>  239
# 632  =>  239
# 633  =>  239
# 634  =>  239
# 635  =>  239
# 636  =>  239
# 637  =>  239
# 638  =>  239
# 639  =>  239
# 640  =>  239
# 641  =>  239
# 642  =>  239
# 643  =>  239
# 644  =>  239
# 645  =>  239
# 646  =>  239
# 647  =>  239
# 648  =>  239
# 649  =>  239
# 650  =>  239
# 651  =>  239
# 652  =>  239
# 653  =>  239
# 654  =>  239
# 655  =>  239
# 656  =>  239
# 657  =>  239
# 658  =>  239
# 659  =>  239
# 660  =>  239
# 661  =>  239
# 662  =>  239
# 663  =>  239
# 664  =>  239
# 665  =>  239
# 666  =>  239
# 667  =>  239
# 668  =>  239
# 669  =>  239
# 670  =>  239
# 671  =>  239
# 672  =>  239
# 673  =>  239
# 674  =>  239
# 675  =>  239
# 676  =>  239
# 677  =>  239
# 678  =>  239
# 679  =>  239
# 680  =>  239
# 681  =>  239
# 682  =>  239
# 683  =>  239
# 684  =>  239
# 685  =>  239
# 686  =>  239
# 687  =>  239
# 688  =>  239
# 689  =>  239
# 690  =>  239
# 691  =>  239
# 692  =>  239
# 693  =>  239
# 694  =>  239
# 695  =>  239
# 696  =>  239
# 697  =>  239
# 698  =>  239
# 699  =>  239
# 700  =>  239
# 701  =>  239
# 702  =>  239

# %%
encoded_habs_clusters = {
    key: [transformer.encode_vec(vec) for vec in habs_clusters[key]]
    for key in habs_clusters
}
encoded_habs_clusters[0]
# Out:
# [['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика'],
#  ['Научная фантастика']]

# %%
encoded_habs_clusters[23]
# Out:
# [['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение'],
#  ['Машинное обучение']]

# %%
encoded_habs_clusters[600]
# Out:
# [['Бизнес-модели', 'Управление e-commerce'],
#  ['Бизнес-модели', 'Управление e-commerce'],
#  ['Бизнес-модели', 'Управление e-commerce'],
#  ['Бизнес-модели', 'Управление e-commerce'],
#  ['Бизнес-модели', 'Управление e-commerce']]
